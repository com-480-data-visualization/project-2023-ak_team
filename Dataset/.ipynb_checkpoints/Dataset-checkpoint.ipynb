# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np

# %%
poster = pd.read_csv('poster.csv')
poster = poster.drop(['id','action','year','rating', 'adventure','comedy','crime','drama','fantasy','horror','mystery','romance','sci-fi','short','thriller','animation'], axis=1)
poster.rename(columns={"title": "Film"}, inplace=True)

# %%
big_actor_movie = pd.read_csv('actorfilms.csv')  
df_big_actor_movie = big_actor_movie[['Film', 'Actor','Year','Rating']]
df_big_actor_movie
# Out:
#                                   Film                Actor  Year  Rating
# 0                          Ghost Story         Fred Astaire  1981     6.3
# 1                      The Purple Taxi         Fred Astaire  1977     6.6
# 2                The Amazing Dobermans         Fred Astaire  1976     5.3
# 3                 The Towering Inferno         Fred Astaire  1974     7.0
# 4                            Midas Run         Fred Astaire  1969     4.8
# ...                                ...                  ...   ...     ...
# 191868                     Jojo Rabbit  Roman Griffin Davis  2019     7.9
# 191869                       Silk Road            Lexi Rabe  2021     5.9
# 191870               Avengers: Endgame            Lexi Rabe  2019     8.4
# 191871  Godzilla: King of the Monsters            Lexi Rabe  2019     6.0
# 191872                   Wander Darkly      Inde Navarrette  2020     5.8
#
# [191873 rows x 4 columns]

# %%
big_actors = np.unique(df_big_actor_movie['Actor'])
big_films = np.unique(df_big_actor_movie['Film'])


big_actor_by_film = dict.fromkeys(big_films, [])
big_actor_by_film

for i in range(len(df_big_actor_movie)):
    big_actor_by_film[df_big_actor_movie['Film'][i]] = big_actor_by_film[df_big_actor_movie['Film'][i]] + [df_big_actor_movie['Actor'][i]]

# %%
big_actor_by_film_df = pd.DataFrame(big_actor_by_film.items(), columns = ['Film', 'Actor list'])
big_actor_by_film_df.head()
# Out:
#              Film                                         Actor list
# 0  !Ay, mi madre!                                         [Paz Vega]
# 1    !Hay motivo!                          [Luis Tosar, Marta Etura]
# 2  !Three Amigos!  [Steve Martin, Chevy Chase, Jon Lovitz, Joe Ma...
# 3          #Alive                                    [Park Shin-Hye]
# 4         #Horror  [Timothy Hutton, Balthazar Getty, Chloe Sevign...

# %%
df = pd.merge(big_actor_by_film_df, poster, on="Film")
df.head()
# Out:
#            Film                                         Actor list  \
# 0        #Alive                                    [Park Shin-Hye]
# 1       #Horror  [Timothy Hutton, Balthazar Getty, Chloe Sevign...
# 2      #Iamhere                                        [Bae Doona]
# 3        #NAME?                   [Ray Milland, Robert Montgomery]
# 4  #REALITYHIGH  [Kate Walsh, John Michael Higgins, Anne Winter...
#
#                                               poster                     genre
# 0  https://m.media-amazon.com/images/M/MV5BMGNiYj...     action, drama, horror
# 1  https://m.media-amazon.com/images/M/MV5BMjM5OD...      crime, drama, horror
# 2  https://m.media-amazon.com/images/M/MV5BZjRhN2...                    comedy
# 3  https://m.media-amazon.com/images/M/MV5BNzdlZj...  animation, short, comedy
# 4  https://m.media-amazon.com/images/M/MV5BNDU3Mz...    comedy, drama, romance

# %%
df = df.drop_duplicates(subset=['Film'])
df = df.reset_index()
df.head()
# Out:
#    index          Film                                         Actor list  \
# 0      0        #Alive                                    [Park Shin-Hye]
# 1      1       #Horror  [Timothy Hutton, Balthazar Getty, Chloe Sevign...
# 2      2      #Iamhere                                        [Bae Doona]
# 3      3        #NAME?                   [Ray Milland, Robert Montgomery]
# 4      4  #REALITYHIGH  [Kate Walsh, John Michael Higgins, Anne Winter...
#
#                                               poster                     genre
# 0  https://m.media-amazon.com/images/M/MV5BMGNiYj...     action, drama, horror
# 1  https://m.media-amazon.com/images/M/MV5BMjM5OD...      crime, drama, horror
# 2  https://m.media-amazon.com/images/M/MV5BZjRhN2...                    comedy
# 3  https://m.media-amazon.com/images/M/MV5BNzdlZj...  animation, short, comedy
# 4  https://m.media-amazon.com/images/M/MV5BNDU3Mz...    comedy, drama, romance

# %%
actors = np.unique(df['Actor list'])
genre = np.unique(df['genre'].str.split(', ').sum())
movie = np.unique(df['Film'].str.split(', ').sum())

# %%
combined_list = []

for lst in actors:
    combined_list.extend(lst)

unique_list = list(set(combined_list))

# %%
unique_list = np.array(unique_list)

# %%
unique_list
# Out:
# array(['Lia McHugh', 'Tony Chiu-Wai Leung', 'Rick Cosnett', ...,
#        'Aja Naomi King', 'Amy Pietz', 'Nate Corddry'], dtype='<U27')

# %%
df['Actor_List_id'] = df['Actor list'].apply(lambda x: [np.where(unique_list == i)[0][0] for i in x])

# %%
df.head()
# Out:
#    index          Film                                         Actor list  \
# 0      0        #Alive                                    [Park Shin-Hye]
# 1      1       #Horror  [Timothy Hutton, Balthazar Getty, Chloe Sevign...
# 2      2      #Iamhere                                        [Bae Doona]
# 3      3        #NAME?                   [Ray Milland, Robert Montgomery]
# 4      4  #REALITYHIGH  [Kate Walsh, John Michael Higgins, Anne Winter...
#
#                                               poster  \
# 0  https://m.media-amazon.com/images/M/MV5BMGNiYj...
# 1  https://m.media-amazon.com/images/M/MV5BMjM5OD...
# 2  https://m.media-amazon.com/images/M/MV5BZjRhN2...
# 3  https://m.media-amazon.com/images/M/MV5BNzdlZj...
# 4  https://m.media-amazon.com/images/M/MV5BNDU3Mz...
#
#                       genre                         Actor_List_id
# 0     action, drama, horror                                [5961]
# 1      crime, drama, horror   [8821, 2007, 137, 3735, 7989, 4045]
# 2                    comedy                                [7261]
# 3  animation, short, comedy                          [2687, 6031]
# 4    comedy, drama, romance  [7375, 3934, 2782, 4006, 5294, 8396]

# %%
adj_matrix = np.zeros((len(unique_list),len(unique_list)))

# %%
for i in range(len(df)):
    for j in range(len(df['Actor_List_id'][i])-1):
        for k in range(j+1,len(df['Actor_List_id'][i])-1):
            adj_matrix[df['Actor_List_id'][i][j]][df['Actor_List_id'][i][k]] = adj_matrix[df['Actor_List_id'][i][j]][df['Actor_List_id'][i][k]]+ 1
            adj_matrix[df['Actor_List_id'][i][k]][df['Actor_List_id'][i][j]] = adj_matrix[df['Actor_List_id'][i][k]][df['Actor_List_id'][i][j]]+ 1

# %%
adj_matrix[6094][4040]
# Out:
# 1.0

# %%
filtered_df = df[df['Actor list'].apply(lambda x:"Robert De Niro" in x)]
filtered_df
# Out:
#        index                     Film  \
# 725      826          American Hustle
# 1297    1470              Being Flynn
# 2812    3271            Dirty Grandpa
# 3213    3753         Everybody's Fine
# 3479    4057                 Flawless
# 3593    4194              Freelancers
# 3901    4561       Great Expectations
# 4103    4790                    Heist
# 4173    4877            Hide and Seek
# 4853    5669                    Joker
# 5017    5855             Killer Elite
# 5040    5879           Killing Season
# 5215    6065               Last Vegas
# 5345    6217                Limitless
# 5373    6251           Little Fockers
# 5623    6534                  Machete
# 5815    6761         Meet the Parents
# 6267    7285           New Year's Eve
# 7230    8420               Red Lights
# 7354    8574           Righteous Kill
# 7831    9163  Silver Linings Playbook
# 8137    9530                 Stardust
# 8199    9602                    Stone
# 8572   10023         The Ages of Love
# 8648   10110              The Bag Man
# 8702   10175          The Big Wedding
# 8870   10388             The Comedian
# 9110   10691               The Family
# 9427   11068               The Intern
# 9559   11220          The Last Tycoon
# 10409  12250        The Wedding Party
# 11172  13152       What Just Happened
#
#                                               Actor list  \
# 725    [Robert De Niro, Christian Bale, Anthony Zerbe...
# 1297   [Robert De Niro, Julianne Moore, Lili Taylor, ...
# 2812   [Robert De Niro, Danny Glover, Dermot Mulroney...
# 3213   [Marcello Mastroianni, Drew Barrymore, Robert ...
# 3479   [Robert De Niro, Demi Moore, Michael Caine, Ph...
# 3593   [Robert De Niro, Dana Delany, Forest Whitaker,...
# 3901   [Alec Guinness, Robert De Niro, Ralph Fiennes,...
# 4103   [Robert De Niro, Danny DeVito, Gene Hackman, D...
# 4173   [Robert De Niro, Elisabeth Shue, Famke Janssen...
# 4853   [Robert De Niro, Joaquin Phoenix, Bryan Callen...
# 5017   [Robert De Niro, Jason Statham, Adewale Akinnu...
# 5040   [Robert De Niro, John Travolta, Milo Ventimiglia]
# 5215   [Robert De Niro, Michael Douglas, Morgan Freem...
# 5345   [Robert De Niro, Robert John Burke, Bradley Co...
# 5373   [Robert De Niro, Dustin Hoffman, Harvey Keitel...
# 5623   [Robert De Niro, Steven Seagal, Don Johnson, R...
# 5815   [Robert De Niro, Blythe Danner, Teri Polo, Ben...
# 6267   [Matthew Broderick, Robert De Niro, Cary Elwes...
# 7230   [Robert De Niro, Sigourney Weaver, Joely Richa...
# 7354   [Robert De Niro, Al Pacino, John Leguizamo, Br...
# 7831   [Robert De Niro, Chris Tucker, Dash Mihok, Jul...
# 8137   [Claire Danes, Robert De Niro, Michelle Pfeiff...
# 8199   [Robert De Niro, Milla Jovovich, Edward Norton...
# 8572   [Robert De Niro, Monica Bellucci, Riccardo Sca...
# 8648   [John Cusack, Robert De Niro, Crispin Glover, ...
# 8702   [Robert De Niro, Susan Sarandon, Robin William...
# 8870   [Robert De Niro, Harvey Keitel, Billy Crystal,...
# 9110   [Robert De Niro, Tommy Lee Jones, Michelle Pfe...
# 9427   [Robert De Niro, Michael Mann, Rene Russo, Ann...
# 9559   [Robert Mitchum, Robert De Niro, Jack Nicholso...
# 10409  [Robert De Niro, Jill Clayburgh, Essie Davis, ...
# 11172  [Robert De Niro, Bruce Willis, Sean Penn, Mich...
#
#                                                   poster  \
# 725    https://m.media-amazon.com/images/M/MV5BMmM4Yz...
# 1297   https://m.media-amazon.com/images/M/MV5BMjI1OT...
# 2812   https://m.media-amazon.com/images/M/MV5BMzk0Nz...
# 3213   https://m.media-amazon.com/images/M/MV5BMTM1Nz...
# 3479   https://m.media-amazon.com/images/M/MV5BMjA1NT...
# 3593   https://m.media-amazon.com/images/M/MV5BMjEyNj...
# 3901   https://m.media-amazon.com/images/M/MV5BMjMzOD...
# 4103   https://m.media-amazon.com/images/M/MV5BMjEzNT...
# 4173   https://m.media-amazon.com/images/M/MV5BNWY2ZT...
# 4853   https://m.media-amazon.com/images/M/MV5BNGVjNW...
# 5017   https://m.media-amazon.com/images/M/MV5BMTc4MD...
# 5040   https://m.media-amazon.com/images/M/MV5BOTQ2Mz...
# 5215   https://m.media-amazon.com/images/M/MV5BMTQ2OD...
# 5345   https://m.media-amazon.com/images/M/MV5BMTA4OD...
# 5373   https://m.media-amazon.com/images/M/MV5BMTkwNj...
# 5623   https://m.media-amazon.com/images/M/MV5BZWUxOD...
# 5815   https://m.media-amazon.com/images/M/MV5BMjA3OT...
# 6267   https://m.media-amazon.com/images/M/MV5BMjI2Mz...
# 7230   https://m.media-amazon.com/images/M/MV5BMTQzMj...
# 7354   https://m.media-amazon.com/images/M/MV5BMTYwMj...
# 7831   https://m.media-amazon.com/images/M/MV5BMTM2MT...
# 8137   https://m.media-amazon.com/images/M/MV5BYTc4OT...
# 8199   https://m.media-amazon.com/images/M/MV5BMTgxOT...
# 8572   https://m.media-amazon.com/images/M/MV5BNTMzYW...
# 8648   https://m.media-amazon.com/images/M/MV5BMjE4ND...
# 8702   https://m.media-amazon.com/images/M/MV5BMTcwOD...
# 8870   https://m.media-amazon.com/images/M/MV5BMTgyOT...
# 9110   https://m.media-amazon.com/images/M/MV5BMTg1Mj...
# 9427   https://m.media-amazon.com/images/M/MV5BMTUyNj...
# 9559   https://m.media-amazon.com/images/M/MV5BZDVhOT...
# 10409  https://m.media-amazon.com/images/M/MV5BNzZlMD...
# 11172  https://m.media-amazon.com/images/M/MV5BNTEyMD...
#
#                          genre  \
# 725               crime, drama
# 1297                     drama
# 2812                    comedy
# 3213                     drama
# 3479    crime, drama, thriller
# 3593      action, crime, drama
# 3901            drama, romance
# 4103      action, crime, drama
# 4173    crime, drama, thriller
# 4853    crime, drama, thriller
# 5017          action, thriller
# 5040   action, drama, thriller
# 5215             comedy, drama
# 5345      comedy, crime, drama
# 5373           comedy, romance
# 5623   action, crime, thriller
# 5815                    comedy
# 6267           comedy, romance
# 7230    drama, fantasy, horror
# 7354     crime, drama, mystery
# 7831    comedy, drama, romance
# 8137                     drama
# 8199           drama, thriller
# 8572           comedy, romance
# 8648      action, crime, drama
# 8702    comedy, drama, romance
# 8870    comedy, drama, romance
# 9110            drama, mystery
# 9427             comedy, drama
# 9559                     drama
# 10409          comedy, romance
# 11172            comedy, drama
#
#                                            Actor_List_id
# 725    [4040, 8169, 4650, 2522, 4975, 1213, 6575, 789...
# 1297   [4040, 5723, 7138, 7338, 7640, 6899, 8714, 592...
# 2812   [4040, 1234, 5019, 3739, 8948, 6100, 7429, 289...
# 3213   [6858, 812, 4040, 1228, 5706, 1839, 54, 7960, ...
# 3479   [4040, 2175, 8519, 2937, 6726, 4968, 5881, 692...
# 3593   [4040, 5959, 2422, 2895, 6863, 2958, 7287, 568...
# 3901   [2779, 4040, 1276, 7856, 1410, 7031, 1455, 285...
# 4103   [4040, 7776, 7554, 6913, 389, 8814, 3931, 5706...
# 4173   [4040, 2040, 234, 8383, 7121, 5913, 6639, 7960...
# 4853   [4040, 3586, 3603, 6068, 4988, 6308, 3079, 803...
# 5017   [4040, 1047, 6019, 7462, 2159, 3625, 753, 8241...
# 5040                                   [4040, 906, 5709]
# 5215   [4040, 1648, 2287, 500, 3417, 5141, 6203, 4311...
# 5345          [4040, 5913, 7892, 5793, 7159, 5360, 4818]
# 5373   [4040, 2325, 2618, 4519, 4003, 425, 1201, 8296...
# 5623   [4040, 6964, 100, 4189, 4812, 8677, 5325, 6389...
# 5815   [4040, 425, 1201, 8296, 2621, 2578, 8157, 3999...
# 6267   [8772, 4040, 2075, 5615, 2449, 7574, 7240, 192...
# 7230   [4040, 6698, 4095, 5649, 5164, 6457, 3280, 815...
# 7354   [4040, 6094, 7352, 1641, 3701, 8692, 5531, 796...
# 7831   [4040, 521, 2552, 5207, 7716, 7892, 3452, 1416...
# 8137   [4887, 4040, 2449, 1265, 5285, 8705, 6558, 119...
# 8199                [4040, 4388, 7887, 5243, 4988, 4938]
# 8572                                  [4040, 5829, 4419]
# 8648                             [7008, 4040, 8424, 753]
# 8702   [4040, 2945, 249, 659, 5877, 4671, 286, 4401, ...
# 8870   [4040, 2618, 8741, 7776, 3611, 5671, 8023, 740...
# 9110   [4040, 5271, 2449, 5835, 7657, 6530, 5423, 196...
# 9427   [4040, 1472, 881, 2685, 4240, 6662, 8483, 349,...
# 9559   [1096, 4040, 8528, 8962, 4382, 1026, 5411, 437...
# 10409           [4040, 7959, 8817, 212, 7687, 574, 1188]
# 11172  [4040, 5546, 7230, 6230, 4122, 8569, 5778, 642...

# %%
filtered_df = df[df['Film'].apply(lambda x:"Shining" in x)]
filtered_df
# Out:
# Empty DataFrame
# Columns: [index, Film, Actor list, poster, genre, Actor_List_id]
# Index: []
